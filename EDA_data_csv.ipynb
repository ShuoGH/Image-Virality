# %% [markdown]
# # EDA of the data set

# %%
import pandas as pd

# %%
df=pd.read_csv("data_set_iv.csv")

# %%
df
# Out:
#        img_id                                           img_link  SNAP_id  \
# 0       10354  http://brie.uchicago.edu/ftp-www/Viral_total/1...    25049
# 1        9487  http://brie.uchicago.edu/ftp-www/Viral_total/9...    23607
# 2        1008  http://brie.uchicago.edu/ftp-www/Viral_total/1...    11336
# 3        8086  http://brie.uchicago.edu/ftp-www/Viral_total/8...    21410
# 4       10256  http://brie.uchicago.edu/ftp-www/Viral_total/1...    24876
# 5       15011  http://brie.uchicago.edu/ftp-www/Viral_total/1...     7782
# 6       12831  http://brie.uchicago.edu/ftp-www/Viral_total/1...     5054
# 7         509  http://brie.uchicago.edu/ftp-www/Viral_total/5...     1066
# 8       10897  http://brie.uchicago.edu/ftp-www/Viral_total/1...     2672
# 9        9959  http://brie.uchicago.edu/ftp-www/Viral_total/9...    24398
# 10      10167  http://brie.uchicago.edu/ftp-www/Viral_total/1...    24743
# 11      12828  http://brie.uchicago.edu/ftp-www/Viral_total/1...     5050
# ...

# %%
import os

# %%
os.path.split(df.iloc[0]['img_link'])[-1]
# Out:
# '10354.jpg'

# %%
for i in df['img_link']:
    print(i)
# Out:
# http://brie.uchicago.edu/ftp-www/Viral_total/10354.jpg
# http://brie.uchicago.edu/ftp-www/Viral_total/9487.jpg
# http://brie.uchicago.edu/ftp-www/Viral_total/1008.jpg
# http://brie.uchicago.edu/ftp-www/Viral_total/8086.jpg
# http://brie.uchicago.edu/ftp-www/Viral_total/10256.jpg
# http://brie.uchicago.edu/ftp-www/Viral_total/15011.jpg
# http://brie.uchicago.edu/ftp-www/Viral_total/12831.jpg
# http://brie.uchicago.edu/ftp-www/Viral_total/509.jpg
# http://brie.uchicago.edu/ftp-www/Viral_total/10897.jpg
# http://brie.uchicago.edu/ftp-www/Viral_total/9959.jpg
# http://brie.uchicago.edu/ftp-www/Viral_total/10167.jpg
# http://brie.uchicago.edu/ftp-www/Viral_total/12828.jpg
# http://brie.uchicago.edu/ftp-www/Viral_total/10275.jpg
# http://brie.uchicago.edu/ftp-www/Viral_total/6899.jpg
# http://brie.uchicago.edu/ftp-www/Viral_total/13306.jpg
# http://brie.uchicago.edu/ftp-www/Viral_total/8627.jpg
# http://brie.uchicago.edu/ftp-www/Viral_total/11762.jpg
# ...
